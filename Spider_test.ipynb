# %% [markdown]
#  Test for radar spider

# %%
import pandas as pd

# %%
proportion_cell_expression= pd.read_csv("data/single_cell/proportion_cell_type_div.csv", index_col=0)
proportion_cell_expression
# Out:
#          Adipocyte     ArtEC    B-cell  B-plasma     CapEC      EnFB  \
# Gene
# ACIN1     0.056895  0.028495  0.020161  0.028224  0.025728  0.023715
# ADA       0.005177  0.054744  0.018727  0.077637  0.099438  0.013403
# AK1       0.010850  0.024895  0.001595  0.004944  0.014916  0.028652
# ALDOA     0.000000  0.024520  0.010479  0.027160  0.030048  0.021815
# AS3MT     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# BLCAP     0.056833  0.018534  0.013849  0.009837  0.017839  0.009495
# CA3       0.011376  0.001681  0.001725  0.002329  0.002919  0.001764
# CALM1     0.009206  0.047362  0.022876  0.023959  0.043271  0.018681
# CCNI      0.010800  0.026107  0.033162  0.016100  0.029505  0.043540
# CLIC4     0.043213  0.064743  0.013408  0.025405  0.062231  0.031662
# CLIC6     0.130727  0.001124  0.000875  0.000000  0.000000  0.007468
# CUTC      0.032790  0.012246  0.004666  0.008672  0.013490  0.016178
# ...

# %%
pwd
# Out:
# '/home/karen/Documents/GitHub/shinny'

# %%
expression_cell = pd.read_csv("data/single_cell/mean_expression_cell.csv", index_col=0)
expression_cell.head()
# Out:
#        Adipocyte     ArtEC    B-cell  B-plasma     CapEC      EnFB  \
# Gene
# ACIN1   0.417506  0.209104  0.147946  0.207114  0.188800  0.174024
# ADA     0.014123  0.149343  0.051087  0.211794  0.271267  0.036564
# AK1     0.033758  0.077454  0.004963  0.015381  0.046405  0.089141
# ALDOA   0.000000  0.170275  0.072773  0.188611  0.208669  0.151496
# AS3MT   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#        Eosinophil        FB       Hyb   LymphEC  ...  Specialised MF  \
# Gene                                             ...
# ACIN1    0.315649  0.232859  0.249706  0.180436  ...        0.210590
# ADA      0.021994  0.183599  0.001473  0.029182  ...        0.006037
# AK1      0.000000  0.067482  0.057971  0.310814  ...        0.095611
# ALDOA    0.031045  0.130680  0.000000  0.230462  ...        0.146612
# AS3MT    0.000000  0.000000  0.000000  0.001418  ...        0.000367
#
#          T-cell  Tenocyte     VenEC      cDC1      cDC2  mSchwann  nmSchwann  \
# ...

# %%
expression_cell.columns
# Out:
# Index(['Adipocyte', 'ArtEC', 'B-cell', 'B-plasma', 'CapEC', 'EnFB',
#        'Eosinophil', 'FB', 'Hyb', 'LymphEC', 'MF-I', 'MF-II', 'MF-IIsc(fg)',
#        'MF-IIsn(fg)', 'MF-Isc(fg)', 'MF-Isn(fg)', 'Macrophage', 'Mast',
#        'Mesothelium', 'Monocyte', 'MuSC', 'NK-cell', 'Neutrophil', 'Pericyte',
#        'PnFB', 'RBC', 'SMC', 'Specialised MF', 'T-cell', 'Tenocyte', 'VenEC',
#        'cDC1', 'cDC2', 'mSchwann', 'nmSchwann', 'pDC', 'most abundant in'],
#       dtype='object')

# %%
cell_proportion = pd.read_csv("data/single_cell/proportion_cell_type.csv", index_col=0)
cell_proportion.head()
# Out:
#            Proportion
# Cell Type
# MF-I         0.229590
# MF-II        0.155917
# FB           0.152461
# MuSC         0.110367
# SMC          0.043945

# %%
expression_cell = expression_cell.drop(columns=["most abundant in"])
sum_expression_cell = expression_cell.sum()
sum_expression_gene = expression_cell.sum(axis=1)
sum_expression_gene
# Out:
# Gene
# ACIN1       7.338225
# ADA         2.728004
# AK1         3.111199
# ALDOA       6.944422
# AS3MT       0.005630
# BLCAP      11.143511
# CA3        14.346652
# CALM1      47.960682
# CCNI       39.537113
# CLIC4      13.185764
# CLIC6       0.741470
# CUTC       10.512179
# EEF2       48.351036
# EHMT1       7.205035
# EIF3C      11.010674
# ENO3       19.439166
# ERI3        5.602769
# FEZ2       17.410056
# GLB1L       0.381922
# GPX7        1.133903
# HBA2        4.509185
# HNRNPM     19.931910
# KL          0.454228
# KLRB1       2.647401
# MAST1       0.082726
# MB         24.627204
# MEIS2       4.987768
# MICU1       8.899819
# MMP23B      0.743901
# MYL2       22.120967
# NDUFB4     26.772435
# PARK7      30.855808
# RECQL       4.840654
# RNF7       14.956187
# RPL13A     91.701693
# RPS24      84.315425
# SBDS       23.805578
# SLC16A3     6.775356
# STIM1       7.732088
# STUM        0.520920
# TAF9B       1.822598
# TNNI1      14.962823
# TPM3       35.764859
# ...

# %%
import plotly.express as px
import pandas as pd

# %%
def print_radar_spyder(gene="ALDOA", expression=None, categories = None):
       if expression is None:
              return None
       if categories is None:
              categories = ['Adipocyte', 'ArtEC', 'B-cell', 'B-plasma', 'CapEC', 'EnFB',
              'Eosinophil', 'FB', 'Hyb', 'LymphEC', 'MF-I', 'MF-II', 'MF-IIsc(fg)',
              'MF-IIsn(fg)', 'MF-Isc(fg)', 'MF-Isn(fg)', 'Macrophage', 'Mast',
              'Mesothelium', 'Monocyte', 'MuSC', 'NK-cell', 'Neutrophil', 'Pericyte',
              'PnFB', 'RBC', 'SMC', 'Specialised MF', 'T-cell', 'Tenocyte', 'VenEC',
              'cDC1', 'cDC2', 'mSchwann', 'nmSchwann', 'pDC']

       df = expression.loc[gene]
       df = pd.DataFrame(df)

       max_category = df[gene].idxmax()
    
       # Define color mapping
       color_map = {
              'Muscle Cells': 'red',
              'Lymphoid': 'blue',
              'Myeloid': 'blue',
              'Connective Tissue': 'orange',
              'Nervous System': 'purple',
              'Support Cells': 'yellow'
       }

       # Default to pink if not in the defined categories
       color = color_map.get(max_category, 'pink')

       fig = px.line_polar(df, r = gene, theta=categories, line_close=True)
       fig.update_traces(fill='toself', line=dict(color=color))
       #fig.show()
       return fig

# %%
def generate_goScatter(genes=["ALDOA"], expression=None, categories=None):
       if expression is None:
              return None
       if categories is None:
              categories = ['Adipocyte', 'ArtEC', 'B-cell', 'B-plasma', 'CapEC', 'EnFB',
              'Eosinophil', 'FB', 'Hyb', 'LymphEC', 'MF-I', 'MF-II', 'MF-IIsc(fg)',
              'MF-IIsn(fg)', 'MF-Isc(fg)', 'MF-Isn(fg)', 'Macrophage', 'Mast',
              'Mesothelium', 'Monocyte', 'MuSC', 'NK-cell', 'Neutrophil', 'Pericyte',
              'PnFB', 'RBC', 'SMC', 'Specialised MF', 'T-cell', 'Tenocyte', 'VenEC',
              'cDC1', 'cDC2', 'mSchwann', 'nmSchwann', 'pDC']
       #df = pd.DataFrame(df)
       fig = go.Figure()
       for gene in genes:
              fig.add_trace(go.Scatterpolar(r = expression.loc[gene], theta=categories, fill='toself', name = gene))
       return fig

# %%
proportion_cell_expression = expression_cell.div(sum_expression_gene.values,axis=0)

# %%
proportion_cell_expression.to_csv("data/single_cell/proportion_cell_type_div.csv")

# %%
print_radar_spyder(gene="ALDOA", expression=expression_cell)

# %%
expression_cell.index
# Out:
# Index(['ACIN1', 'ADA', 'AK1', 'ALDOA', 'AS3MT', 'BLCAP', 'CA3', 'CALM1',
#        'CCNI', 'CLIC4', 'CLIC6', 'CUTC', 'EEF2', 'EHMT1', 'EIF3C', 'ENO3',
#        'ERI3', 'FEZ2', 'GLB1L', 'GPX7', 'HBA2', 'HNRNPM', 'KL', 'KLRB1',
#        'MAST1', 'MB', 'MEIS2', 'MICU1', 'MMP23B', 'MYL2', 'NDUFB4', 'PARK7',
#        'RECQL', 'RNF7', 'RPL13A', 'RPS24', 'SBDS', 'SLC16A3', 'STIM1', 'STUM',
#        'TAF9B', 'TNNI1', 'TPM3', 'UBE2H', 'NT5C2'],
#       dtype='object', name='Gene')

# %%
cells= ['Adipocyte', 'ArtEC', 'B-cell', 'B-plasma', 'CapEC', 'EnFB',
              'Eosinophil', 'FB', 'Hyb', 'LymphEC', 'MF-I', 'MF-II', 'MF-IIsc(fg)',
              'MF-IIsn(fg)', 'MF-Isc(fg)', 'MF-Isn(fg)', 'Macrophage', 'Mast',
              'Mesothelium', 'Monocyte', 'MuSC', 'NK-cell', 'Neutrophil', 'Pericyte',
              'PnFB', 'RBC', 'SMC', 'Specialised MF', 'T-cell', 'Tenocyte', 'VenEC',
              'cDC1', 'cDC2', 'mSchwann', 'nmSchwann', 'pDC']

# %%
import plotly.graph_objects as go

generate_goScatter(genes = ['ACIN1', 'MYL2', 'FEZ2', 'ALDOA'], expression=proportion_cell_expression)

# %%
cell_groups = pd.read_csv("data/single_cell/Cell_type_classification.csv")
cell_groups
# Out:
#       Abbreviation                                      Full Name  \
# 0             EnFB                          Endomysial Fibroblast
# 1               FB                                     Fibroblast
# 2             PnFB                         Perineurial Fibroblast
# 3         Tenocyte                                       Tenocyte
# 4           B-cell                                   B Lymphocyte
# 5         B-plasma                                  Plasma B Cell
# 6          NK-cell                            Natural Killer Cell
# 7              Hyb                                Hybrid Myofiber
# 8             MF-I                                Myofiber Type I
# 9            MF-II                               Myofiber Type II
# 10     MF-IIsc(fg)  Myofiber Type II Subcluster (fast glycolytic)
# 11     MF-IIsn(fg)   Myofiber Type II Subcluster (slow oxidative)
# 12      MF-Isc(fg)   Myofiber Type I Subcluster (fast glycolytic)
# ...

# %%
# Rename columns using dataframe B
A = expression_cell.rename(columns=dict(zip(cell_groups['Abbreviation'], cell_groups['Classification'])))

# Sum columns with the same name
A = A.groupby(level=0, axis=1).sum()
A.head()
# Out:
# /tmp/ipykernel_209289/1780591889.py:5: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#        Connective Tissue  Lymphoid  Muscle Cells   Myeloid  Nervous System  \
# Gene
# ACIN1           0.811384  0.611670      1.567632  2.369213        0.298581
# ADA             0.253970  0.418511      0.027385  1.161621        0.032909
# AK1             0.301947  0.026792      1.676427  0.171675        0.194650
# ALDOA           0.501847  0.372718      3.197685  1.339121        0.250235
# AS3MT           0.000000  0.000000      0.001111  0.000367        0.000000
#
#        Red Blood Cell  Support Cells  Vascular Cells
# Gene
# ACIN1        0.125104       0.616409        0.938233
# ADA          0.000000       0.022080        0.811529
# AK1          0.065073       0.092971        0.581665
# ALDOA        0.000000       0.160352        1.122465
# AS3MT        0.000000       0.002293        0.001859

# %%
cells = A.columns.to_list()

# %%
cells
# Out:
# ['Connective Tissue',
#  'Lymphoid',
#  'Muscle Cells',
#  'Myeloid',
#  'Nervous System',
#  'Red Blood Cell',
#  'Support Cells',
#  'Vascular Cells']

# %%
A.index
# Out:
# Index(['ACIN1', 'ADA', 'AK1', 'ALDOA', 'AS3MT', 'BLCAP', 'CA3', 'CALM1',
#        'CCNI', 'CLIC4', 'CLIC6', 'CUTC', 'EEF2', 'EHMT1', 'EIF3C', 'ENO3',
#        'ERI3', 'FEZ2', 'GLB1L', 'GPX7', 'HBA2', 'HNRNPM', 'KL', 'KLRB1',
#        'MAST1', 'MB', 'MEIS2', 'MICU1', 'MMP23B', 'MYL2', 'NDUFB4', 'PARK7',
#        'RECQL', 'RNF7', 'RPL13A', 'RPS24', 'SBDS', 'SLC16A3', 'STIM1', 'STUM',
#        'TAF9B', 'TNNI1', 'TPM3', 'UBE2H', 'NT5C2'],
#       dtype='object', name='Gene')

# %%
gene = 'EIF3C'
fig = print_radar_spyder(gene=gene, expression=A, categories=cells)
print(gene)
fig.show()
# Out:
# EIF3C

# %%
for gene in A.index :
    fig = print_radar_spyder(gene=gene, expression=A, categories=cells)
    # save fig in svg
    #fig.write_image(f"{gene}_radar.svg")
    print(gene)
    fig.show()
# Out:
# ACIN1
# ADA
# AK1
# ALDOA
# AS3MT
# BLCAP
# CA3
# CALM1
# CCNI
# CLIC4
# CLIC6
# CUTC
# EEF2
# EHMT1
# EIF3C
# ENO3
# ERI3
# FEZ2
# GLB1L
# GPX7
# HBA2
# HNRNPM
# KL
# KLRB1
# MAST1
# MB
# MEIS2
# MICU1
# MMP23B
# MYL2
# NDUFB4
# PARK7
# RECQL
# RNF7
# RPL13A
# RPS24
# SBDS
# SLC16A3
# STIM1
# STUM
# TAF9B
# TNNI1
# TPM3
# UBE2H
# NT5C2

# %%
A
# Out:
#          Connective Tissue   Lymphoid  Muscle Cells    Myeloid  \
# Gene
# ACIN1             0.811384   0.611670      1.567632   2.369213
# ADA               0.253970   0.418511      0.027385   1.161621
# AK1               0.301947   0.026792      1.676427   0.171675
# ALDOA             0.501847   0.372718      3.197685   1.339121
# AS3MT             0.000000   0.000000      0.001111   0.000367
# BLCAP             0.509864   0.389445      6.176795   1.687320
# CA3               0.235613   0.069273     11.644146   1.473665
# CALM1             3.474458   4.567630     13.102571  12.622368
# CCNI              5.963624   3.023285      6.878318  12.886193
# CLIC4             2.267057   0.521277      2.011786   1.553237
# CLIC6             0.110532   0.000950      0.416893   0.103702
# CUTC              0.752656   0.271883      6.438496   1.403576
# EEF2              6.673709   5.022387     10.928138  12.078038
# EHMT1             0.901624   0.787136      1.435073   1.986355
# ...

# %%
genes = ['NT5C2',
'BLCAP',
'FEZ2',
'STUM',
'EHMT1',
'GPX7',
'AK1']

# %%
for gene in genes :
    if gene in A.index:
        fig = print_radar_spyder(gene=gene, expression=A, categories=cells)
        # save fig in svg
        fig.write_image(f"{gene}_radar.svg")
        print(gene)
        fig.show()
# Out:
# NT5C2
# BLCAP
# FEZ2
# STUM
# EHMT1
# GPX7
# AK1

# %%
print_radar_spyder(gene="MYL2", expression=A, categories=cells)

# %%
generate_goScatter(genes = ['ACIN1', 'MYL2', 'FEZ2', 'ALDOA'], expression=A, categories=cells)

# %%
compact_expression_proportion = A.div(sum_expression_gene.values,axis=0)

# %%
generate_goScatter(genes = ['ACIN1', 'MYL2', 'FEZ2', 'ALDOA'], expression=compact_expression_proportion, categories=cells)
